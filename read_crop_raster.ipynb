# %%
from osgeo import gdal
import subprocess
import os
import matplotlib.pyplot as plt
from matplotlib import pyplot
# %matplotlib inline

# %%
import rasterio
from rasterio import plot
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#import bands as one band raster
# filepath='/Users/payelmallick/Documents/india_district/S2A_MSIL1C_20220905T050711_N0400_R019_T44QKE_20220905T070719.SAFE/GRANULE/L1C_T44QKE_A037625_20220905T051552/IMG_DATA/T44QKE_20220905T050711_B01'

#import bands as separate 1 band raster
imagePath = '/Users/payelmallick/Documents/india_district/S2A_MSIL1C_20220905T050711_N0400_R019_T44QKE_20220905T070719.SAFE/GRANULE/L1C_T44QKE_A037625_20220905T051552/IMG_DATA/'

# %%
band1 = rasterio.open(imagePath+'T44QKE_20220905T050711_B01.jp2') #blue

# %%
band1.meta
# Out:
# {'driver': 'JP2OpenJPEG',
#  'dtype': 'uint16',
#  'nodata': None,
#  'width': 1830,
#  'height': 1830,
#  'count': 1,
#  'crs': CRS.from_epsg(32644),
#  'transform': Affine(60.0, 0.0, 199980.0,
#         0.0, -60.0, 2000040.0)}

# %%
plot.show(band1)
# Out:
# <AxesSubplot:>
